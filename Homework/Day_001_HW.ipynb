# %% [markdown]
# ## 作業 1
# ---
#
# 選擇的競賽為：[Microsoft Malware Prediction](https://www.kaggle.com/c/microsoft-malware-prediction)
#
# 1.你選的這組資料為何重要
# > 隨著惡意軟體的攻擊愈來愈多樣化，愈來愈具組織性，許多傳統或是現階段的安全檢測方式，已不再能夠全面性地預防及阻擋惡意攻擊，往往一旦受到感染，所造成的傷害及損失可能相當慘重，甚至無法挽回，因此，希望能夠借助資料科學，開發出一個只需透過分析機器的各種狀態資訊，便能夠從中預測出該機器可能會受感染的機率為多少的技術，如此一來，就可以為此先做一些預防措施，降低感染的風險。
#
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# > 透過對 Microsoft 的終端設備保護方案 Windows Defender 所蒐集的 heartbeat 和威脅報告做取樣並組合而來的。
#
# 3.蒐集而來的資料型態為何
# > 為結構化的資料，包括機器的識別碼、引擎版本號、偵測的結果以及各種參數資訊，其中的資料型態有字串、數值以及布林值。
# >
# > 資料中有些欄位為不可用的或是 self-documenting 則會標記成 "NA"。
#
# 4.這組資料想解決的問題如何評估
# > 可以透過以下幾種衡量指標去分析及評估：
# >
# >1. MAE: Mean Absolute Error
# >2. MSE: Mean Squared Error
# >3. RMSE: Root Mean Squared Error
# >
# >將根據機器狀態資訊所評估出的感染機率和實際結果作比較，再看比較後的結果是否符合預期，若結果不佳，則繼續修改、優化評估方式，逼近實際值。

# %% [markdown]
# ## 作業 2
# ---
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# > 直覺上，能夠反應出業績提升的就是營收的增加，不過就長期目標而言，該如何透過祭出優惠或是其他的方式，促使接客量的增加，快速地拓展市場，打下品牌的知名度，甚至穩定客群，也是一種在提升業績時值得我們去思考的一環，縱使短時間內營收可能沒有顯著地成長也沒關係。
#
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# > 客人的評價：每次載客結束前，請客人填寫對於此趟旅程的評價和一些建議，或是設計一個 app 可以讓客人線上叫車，並在事後讓客人直接於 app 內填寫問卷。
# >
# > 市場的需求：提供線上和紙本問卷，蒐集一般人對於載客服務的需求，並了解通常在什麼時期、什麼時間點以及什麼場合的需求量最大。
# >
# > 競爭者優於自己的部份：親自當一個乘客，體驗並深入了解競爭者的服務差別在哪。
#
# 3.蒐集而來的資料型態為何
# > 非結構化資料：乘客的回饋。
#
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# > 定期調整可能影響問題的參數，然後追蹤市場的反應。
# >
# > 把時間拉長來看，評估整體的營收有無成長。

# %% [markdown]
# ## 作業 3
# ---
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 265.863
# The Mean absolute error is 12.947
